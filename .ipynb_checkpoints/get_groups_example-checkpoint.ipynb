# %%
import requests, os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
url = os.environ['ZD_URL']+'groups.json'
user = os.environ['ZD_USER']
pwd = os.environ['ZD_PW']

# %%
# Do the HTTP get request
response = requests.get(url, auth=(user, pwd))

# %%
response.json()
# Out:
# {'groups': [{'url': 'https://juicewrld.zendesk.com/api/v2/groups/360010469351.json',
#    'id': 360010469351,
#    'name': '999',
#    'description': '999 Support Agents',
#    'default': False,
#    'deleted': False,
#    'created_at': '2020-07-04T18:54:58Z',
#    'updated_at': '2020-07-19T19:35:43Z'},
#   {'url': 'https://juicewrld.zendesk.com/api/v2/groups/360012947651.json',
#    'id': 360012947651,
#    'name': 'Admin',
#    'description': 'For Merge App',
#    'default': False,
#    'deleted': False,
#    'created_at': '2020-10-16T01:10:12Z',
#    'updated_at': '2020-10-16T01:10:12Z'},
#   {'url': 'https://juicewrld.zendesk.com/api/v2/groups/360016826052.json',
#    'id': 360016826052,
#    'name': 'Bella Poarch',
#    'description': '',
#    'default': False,
#    'deleted': False,
#    'created_at': '2021-03-24T21:38:21Z',
#    'updated_at': '2021-03-24T21:38:21Z'},
#   {'url': 'https://juicewrld.zendesk.com/api/v2/groups/360010838232.json',
#    'id': 360010838232,
#    'name': 'Capalot',
#    'description': '',
#    'default': False,
#    'deleted': False,
#    'created_at': '2020-07-19T19:34:53Z',
#    'updated_at': '2020-07-19T19:34:53Z'},
#   {'url': 'https://juicewrld.zendesk.com/api/v2/groups/360015918532.json',
#    'id': 360015918532,
#    'name': 'Fivio Foreign',
#    'description': 'Fivio Foreign Group',
#    'default': False,
#    'deleted': False,
#    'created_at': '2021-02-14T18:11:37Z',
#    'updated_at': '2021-02-14T18:11:37Z'},
#   {'url': 'https://juicewrld.zendesk.com/api/v2/groups/360015917952.json',
#    'id': 360015917952,
#    'name': 'G Herbo',
#    'description': 'Group for G Herbo',
#    'default': False,
#    'deleted': False,
#    'created_at': '2021-02-14T17:31:40Z',
#    'updated_at': '2021-02-14T17:31:40Z'},
#   {'url': 'https://juicewrld.zendesk.com/api/v2/groups/360015123692.json',
#    'id': 360015123692,
#    'name': 'Instagram',
#    'description': '',
#    'default': False,
#    'deleted': False,
#    'created_at': '2021-01-14T00:51:01Z',
#    'updated_at': '2021-01-14T00:51:01Z'},
#   {'url': 'https://juicewrld.zendesk.com/api/v2/groups/360017010692.json',
#    'id': 360017010692,
#    'name': 'K Suave',
#    'description': 'K Suave Group',
#    'default': False,
#    'deleted': False,
#    'created_at': '2021-03-30T23:33:58Z',
#    'updated_at': '2021-03-30T23:33:58Z'},
#   {'url': 'https://juicewrld.zendesk.com/api/v2/groups/360016826072.json',
#    'id': 360016826072,
#    'name': 'KSI Merch',
#    'description': '',
#    'default': False,
#    'deleted': False,
#    'created_at': '2021-03-24T21:38:39Z',
#    'updated_at': '2021-03-24T21:38:39Z'},
#   {'url': 'https://juicewrld.zendesk.com/api/v2/groups/360013864651.json',
#    'id': 360013864651,
#    'name': 'Lil Durk',
#    'description': '',
#    'default': False,
#    'deleted': False,
#    'created_at': '2020-11-19T23:12:30Z',
#    'updated_at': '2020-11-19T23:12:30Z'},
#   {'url': 'https://juicewrld.zendesk.com/api/v2/groups/360013914092.json',
#    'id': 360013914092,
#    'name': 'Lil Mosey',
#    'description': '',
#    'default': False,
#    'deleted': False,
#    'created_at': '2020-11-21T23:01:44Z',
#    'updated_at': '2020-11-21T23:01:44Z'},
#   {'url': 'https://juicewrld.zendesk.com/api/v2/groups/360013902211.json',
#    'id': 360013902211,
#    'name': 'Lil Tjay',
#    'description': '',
#    'default': False,
#    'deleted': False,
#    'created_at': '2020-11-21T23:02:43Z',
#    'updated_at': '2020-11-21T23:02:43Z'},
#   {'url': 'https://juicewrld.zendesk.com/api/v2/groups/360013914132.json',
#    'id': 360013914132,
#    'name': 'Live Free 999',
#    'description': '',
#    'default': False,
#    'deleted': False,
#    'created_at': '2020-11-21T23:03:18Z',
#    'updated_at': '2020-11-21T23:03:18Z'},
#   {'url': 'https://juicewrld.zendesk.com/api/v2/groups/360010469391.json',
#    'id': 360010469391,
#    'name': 'MAC',
#    'description': 'All ',
#    'default': True,
#    'deleted': False,
#    'created_at': '2020-07-04T18:56:24Z',
#    'updated_at': '2020-07-04T18:58:08Z'},
#   {'url': 'https://juicewrld.zendesk.com/api/v2/groups/360017195572.json',
#    'id': 360017195572,
#    'name': 'Moneybagg Yo ',
#    'description': '',
#    'default': False,
#    'deleted': False,
#    'created_at': '2021-04-07T00:41:29Z',
#    'updated_at': '2021-04-07T00:41:29Z'},
#   {'url': 'https://juicewrld.zendesk.com/api/v2/groups/360012858931.json',
#    'id': 360012858931,
#    'name': 'NBA Youngboy',
#    'description': '',
#    'default': False,
#    'deleted': False,
#    'created_at': '2020-10-13T01:49:26Z',
#    'updated_at': '2020-10-13T01:49:26Z'},
#   {'url': 'https://juicewrld.zendesk.com/api/v2/groups/360016351231.json',
#    'id': 360016351231,
#    'name': 'PTG 365 Merch',
#    'description': '',
#    'default': False,
#    'deleted': False,
#    'created_at': '2021-03-06T01:17:28Z',
#    'updated_at': '2021-03-06T01:17:28Z'},
#   {'url': 'https://juicewrld.zendesk.com/api/v2/groups/360013902231.json',
#    'id': 360013902231,
#    'name': 'The Crew League',
#    'description': '',
#    'default': False,
#    'deleted': False,
#    'created_at': '2020-11-21T23:03:50Z',
#    'updated_at': '2020-11-21T23:03:50Z'},
#   {'url': 'https://juicewrld.zendesk.com/api/v2/groups/360012875612.json',
#    'id': 360012875612,
#    'name': 'The Kid Laroi',
#    'description': '',
#    'default': False,
#    'deleted': False,
#    'created_at': '2020-10-13T01:52:23Z',
#    'updated_at': '2020-10-13T01:52:23Z'},
#   {'url': 'https://juicewrld.zendesk.com/api/v2/groups/360015918292.json',
#    'id': 360015918292,
#    'name': 'Trench Kid',
#    'description': '',
#    'default': False,
#    'deleted': False,
#    'created_at': '2021-02-14T17:55:34Z',
#    'updated_at': '2021-02-14T17:55:34Z'},
#   {'url': 'https://juicewrld.zendesk.com/api/v2/groups/360010857112.json',
#    'id': 360010857112,
#    'name': 'Trippie Redd',
#    'description': '',
#    'default': False,
#    'deleted': False,
#    'created_at': '2020-07-20T20:33:53Z',
#    'updated_at': '2020-07-20T20:33:53Z'},
#   {'url': 'https://juicewrld.zendesk.com/api/v2/groups/360016080211.json',
#    'id': 360016080211,
#    'name': 'Yung Mal',
#    'description': '',
#    'default': False,
#    'deleted': False,
#    'created_at': '2021-02-21T20:23:27Z',
#    'updated_at': '2021-02-21T20:23:27Z'}],
#  'next_page': None,
#  'previous_page': None,
#  'count': 22}
